# %%
# !pip install -r requirements.txt
# Out:
# Ignoring async-timeout: markers 'python_version >= "3.11" and python_full_version < "3.11.3"' don't match your environment
# Ignoring colorama: markers 'python_version >= "3.11" and python_version < "3.12" and (platform_system == "Windows" or os_name == "nt" or sys_platform == "win32")' don't match your environment
# Ignoring nvidia-cublas-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cuda-cupti-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cuda-nvrtc-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cuda-runtime-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cudnn-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cufft-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-curand-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cusolver-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cusparse-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cusparselt-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-nccl-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-nvjitlink-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-nvtx-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring pyreadline3: markers 'sys_platform == "win32" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring pywin32: markers 'sys_platform == "win32" and platform_python_implementation != "PyPy" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring pywinpty: markers 'python_version >= "3.11" and python_version < "3.12" and os_name == "nt"' don't match your environment
# Ignoring triton: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring watchdog: markers 'python_version >= "3.11" and python_version < "3.12" and platform_system != "Darwin"' don't match your environment
# Requirement already satisfied: absl-py==2.1.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: aiofiles==24.1.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (24.1.0)
# Requirement already satisfied: aiohappyeyeballs==2.6.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (2.6.1)
# Requirement already satisfied: aiohttp==3.11.14 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (3.11.14)
# Requirement already satisfied: aiosignal==1.3.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: altair==5.5.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (5.5.0)
# Requirement already satisfied: annotated-types==0.7.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: anthropic==0.49.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (0.49.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (4.9.3)
# Requirement already satisfied: anyio==4.9.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (4.9.0)
# Requirement already satisfied: appdirs==1.4.4 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (1.4.4)
# Requirement already satisfied: appnope==0.1.4 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (0.1.4)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (21.2.0)
# Requirement already satisfied: argon2-cffi==23.1.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (23.1.0)
# Requirement already satisfied: arrow==1.3.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: arxiv==2.1.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 16)) (2.1.3)
# Requirement already satisfied: asgiref==3.8.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 17)) (3.8.1)
# Requirement already satisfied: asttokens==3.0.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 18)) (3.0.0)
# Requirement already satisfied: async-lru==2.0.5 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 19)) (2.0.5)
# Requirement already satisfied: attrs==25.3.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 21)) (25.3.0)
# Requirement already satisfied: azure-ai-inference==1.0.0b9 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from azure-ai-inference[opentelemetry]==1.0.0b9->-r requirements.txt (line 22)) (1.0.0b9)
# Requirement already satisfied: azure-core-tracing-opentelemetry==1.0.0b11 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 23)) (1.0.0b11)
# Requirement already satisfied: azure-core==1.32.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 24)) (1.32.0)
# Requirement already satisfied: azure-cosmos==4.9.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 25)) (4.9.0)
# Requirement already satisfied: azure-identity==1.21.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 26)) (1.21.0)
# Requirement already satisfied: babel==2.17.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 27)) (2.17.0)
# Requirement already satisfied: backoff==2.2.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 28)) (2.2.1)
# Requirement already satisfied: bcrypt==4.3.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 29)) (4.3.0)
# Requirement already satisfied: beautifulsoup4==4.13.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 30)) (4.13.3)
# Requirement already satisfied: bleach==6.2.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from bleach[css]==6.2.0->-r requirements.txt (line 31)) (6.2.0)
# Requirement already satisfied: blinker==1.9.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 32)) (1.9.0)
# Requirement already satisfied: build==1.2.2.post1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 33)) (1.2.2.post1)
# Requirement already satisfied: cachetools==5.5.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 34)) (5.5.2)
# Requirement already satisfied: certifi==2025.1.31 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 35)) (2025.1.31)
# Requirement already satisfied: cffi==1.17.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 36)) (1.17.1)
# Requirement already satisfied: chardet==5.2.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 37)) (5.2.0)
# Requirement already satisfied: charset-normalizer==3.4.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 38)) (3.4.1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 39)) (0.7.6)
# Requirement already satisfied: chromadb==0.6.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 40)) (0.6.3)
# Requirement already satisfied: click==8.1.8 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 41)) (8.1.8)
# Requirement already satisfied: cohere==5.14.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 42)) (5.14.0)
# Requirement already satisfied: coloredlogs==15.0.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 44)) (15.0.1)
# Requirement already satisfied: comm==0.2.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 45)) (0.2.2)
# Requirement already satisfied: contourpy==1.3.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 46)) (1.3.1)
# Requirement already satisfied: cryptography==44.0.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 47)) (44.0.2)
# Requirement already satisfied: cycler==0.12.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 48)) (0.12.1)
# Requirement already satisfied: dataclasses-json==0.6.7 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 49)) (0.6.7)
# Requirement already satisfied: datasets==3.4.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 50)) (3.4.1)
# Requirement already satisfied: debugpy==1.8.13 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 51)) (1.8.13)
# Requirement already satisfied: decorator==5.2.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 52)) (5.2.1)
# Requirement already satisfied: deepl==1.21.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 53)) (1.21.1)
# Requirement already satisfied: defusedxml==0.7.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 54)) (0.7.1)
# Requirement already satisfied: deprecated==1.2.18 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 55)) (1.2.18)
# Requirement already satisfied: dill==0.3.8 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 56)) (0.3.8)
# Requirement already satisfied: dirtyjson==1.0.8 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 57)) (1.0.8)
# Requirement already satisfied: diskcache==5.6.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 58)) (5.6.3)
# Requirement already satisfied: distro==1.9.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 59)) (1.9.0)
# Requirement already satisfied: dnspython==2.7.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 60)) (2.7.0)
# Requirement already satisfied: docx2txt==0.8 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 61)) (0.8)
# Requirement already satisfied: durationpy==0.9 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 62)) (0.9)
# Requirement already satisfied: effdet==0.4.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 63)) (0.4.1)
# Requirement already satisfied: elastic-transport==8.17.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 64)) (8.17.1)
# Requirement already satisfied: elasticsearch==8.17.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from elasticsearch[vectorstore-mmr]==8.17.2->-r requirements.txt (line 65)) (8.17.2)
# Requirement already satisfied: emoji==2.14.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 66)) (2.14.1)
# Requirement already satisfied: et-xmlfile==2.0.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 67)) (2.0.0)
# Requirement already satisfied: eval-type-backport==0.2.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 68)) (0.2.2)
# Requirement already satisfied: executing==2.2.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 69)) (2.2.0)
# Requirement already satisfied: faiss-cpu==1.10.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 70)) (1.10.0)
# Requirement already satisfied: fastapi==0.115.11 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 71)) (0.115.11)
# Requirement already satisfied: fastavro==1.10.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 72)) (1.10.0)
# Requirement already satisfied: fastjsonschema==2.21.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 73)) (2.21.1)
# Requirement already satisfied: feedparser==6.0.11 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 74)) (6.0.11)
# Requirement already satisfied: filelock==3.18.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 75)) (3.18.0)
# Requirement already satisfied: filetype==1.2.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 76)) (1.2.0)
# Requirement already satisfied: flashrank==0.2.10 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 77)) (0.2.10)
# Requirement already satisfied: flatbuffers==25.2.10 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 78)) (25.2.10)
# Requirement already satisfied: fonttools==4.56.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 79)) (4.56.0)
# Requirement already satisfied: fqdn==1.5.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 80)) (1.5.1)
# Requirement already satisfied: frozenlist==1.5.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 81)) (1.5.0)
# Requirement already satisfied: fsspec==2024.12.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 82)) (2024.12.0)
# Requirement already satisfied: ftfy==6.3.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 84)) (6.3.1)
# Requirement already satisfied: gitdb==4.0.12 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 85)) (4.0.12)
# Requirement already satisfied: gitpython==3.1.44 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 86)) (3.1.44)
# Requirement already satisfied: google-ai-generativelanguage==0.6.17 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 87)) (0.6.17)
# Requirement already satisfied: google-api-core==1.34.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from google-api-core[grpc]==1.34.1->-r requirements.txt (line 88)) (1.34.1)
# Requirement already satisfied: google-auth==2.38.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 89)) (2.38.0)
# Requirement already satisfied: google-cloud-vision==3.10.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 90)) (3.10.1)
# Requirement already satisfied: google-search-results==2.4.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 91)) (2.4.2)
# Requirement already satisfied: googleapis-common-protos==1.69.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 92)) (1.69.2)
# Requirement already satisfied: grandalf==0.8 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 93)) (0.8)
# Requirement already satisfied: greenlet==3.1.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 94)) (3.1.1)
# Requirement already satisfied: grpc-gateway-protoc-gen-openapiv2==0.1.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 95)) (0.1.0)
# Requirement already satisfied: grpcio-status==1.48.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 96)) (1.48.2)
# Requirement already satisfied: grpcio==1.67.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 97)) (1.67.1)
# Requirement already satisfied: h11==0.14.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 98)) (0.14.0)
# Requirement already satisfied: html5lib==1.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 99)) (1.1)
# Requirement already satisfied: httpcore==1.0.7 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 100)) (1.0.7)
# Requirement already satisfied: httptools==0.6.4 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 101)) (0.6.4)
# Requirement already satisfied: httpx-sse==0.4.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 102)) (0.4.0)
# Requirement already satisfied: httpx==0.28.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 103)) (0.28.1)
# Requirement already satisfied: huggingface-hub==0.29.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 104)) (0.29.3)
# Requirement already satisfied: humanfriendly==10.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 105)) (10.0)
# Requirement already satisfied: idna==3.10 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 106)) (3.10)
# Requirement already satisfied: importlib-metadata==8.6.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 107)) (8.6.1)
# Requirement already satisfied: importlib-resources==6.5.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 108)) (6.5.2)
# Requirement already satisfied: ipykernel==6.29.5 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 109)) (6.29.5)
# Requirement already satisfied: ipython-pygments-lexers==1.1.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 110)) (1.1.1)
# Requirement already satisfied: ipython==9.0.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 111)) (9.0.2)
# Requirement already satisfied: ipywidgets==8.1.5 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 112)) (8.1.5)
# Requirement already satisfied: isodate==0.7.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 113)) (0.7.2)
# Requirement already satisfied: isoduration==20.11.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 114)) (20.11.0)
# Requirement already satisfied: jedi==0.19.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 115)) (0.19.2)
# Requirement already satisfied: jinja2==3.1.6 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 116)) (3.1.6)
# Requirement already satisfied: jiter==0.9.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 117)) (0.9.0)
# Requirement already satisfied: joblib==1.4.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 118)) (1.4.2)
# Requirement already satisfied: jpype1==1.5.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 119)) (1.5.2)
# Requirement already satisfied: json5==0.10.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 120)) (0.10.0)
# Requirement already satisfied: jsonpatch==1.33 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 121)) (1.33)
# Requirement already satisfied: jsonpointer==3.0.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 122)) (3.0.0)
# Requirement already satisfied: jsonschema-specifications==2024.10.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 123)) (2024.10.1)
# Requirement already satisfied: jsonschema==4.23.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 124)) (4.23.0)
# Requirement already satisfied: jupyter-client==8.6.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 126)) (8.6.3)
# Requirement already satisfied: jupyter-console==6.6.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 127)) (6.6.3)
# Requirement already satisfied: jupyter-core==5.7.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 128)) (5.7.2)
# Requirement already satisfied: jupyter-events==0.12.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 129)) (0.12.0)
# Requirement already satisfied: jupyter-lsp==2.2.5 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 130)) (2.2.5)
# Requirement already satisfied: jupyter-server-terminals==0.5.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 131)) (0.5.3)
# Requirement already satisfied: jupyter-server==2.15.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 132)) (2.15.0)
# Requirement already satisfied: jupyter==1.1.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 133)) (1.1.1)
# Requirement already satisfied: jupyterlab-pygments==0.3.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 134)) (0.3.0)
# Requirement already satisfied: jupyterlab-server==2.27.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 135)) (2.27.3)
# Requirement already satisfied: jupyterlab-widgets==3.0.13 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 136)) (3.0.13)
# Requirement already satisfied: jupyterlab==4.3.6 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 137)) (4.3.6)
# Requirement already satisfied: kiwipiepy-model==0.20.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 138)) (0.20.0)
# Requirement already satisfied: kiwipiepy==0.20.4 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 139)) (0.20.4)
# Requirement already satisfied: kiwisolver==1.4.8 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 140)) (1.4.8)
# Requirement already satisfied: konlpy==0.6.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 141)) (0.6.0)
# Requirement already satisfied: kubernetes==32.0.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 142)) (32.0.1)
# Requirement already satisfied: langchain-anthropic==0.3.10 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 143)) (0.3.10)
# Requirement already satisfied: langchain-azure-ai==0.1.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 144)) (0.1.2)
# Requirement already satisfied: langchain-chroma==0.2.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 145)) (0.2.2)
# Requirement already satisfied: langchain-cohere==0.4.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 146)) (0.4.3)
# Requirement already satisfied: langchain-community==0.3.20 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 147)) (0.3.20)
# Requirement already satisfied: langchain-core==0.3.45 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 148)) (0.3.45)
# Requirement already satisfied: langchain-elasticsearch==0.3.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 149)) (0.3.2)
# Requirement already satisfied: langchain-experimental==0.3.4 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 150)) (0.3.4)
# Requirement already satisfied: langchain-google-genai==2.1.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 151)) (2.1.0)
# Requirement already satisfied: langchain-huggingface==0.1.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 152)) (0.1.2)
# Requirement already satisfied: langchain-milvus==0.1.8 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 153)) (0.1.8)
# Requirement already satisfied: langchain-ollama==0.2.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 154)) (0.2.3)
# Requirement already satisfied: langchain-openai==0.3.9 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 155)) (0.3.9)
# Requirement already satisfied: langchain-teddynote==0.3.44 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 156)) (0.3.44)
# Requirement already satisfied: langchain-text-splitters==0.3.7 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 157)) (0.3.7)
# Requirement already satisfied: langchain==0.3.21 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 158)) (0.3.21)
# Requirement already satisfied: langchainhub==0.1.21 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 159)) (0.1.21)
# Requirement already satisfied: langdetect==1.0.9 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 160)) (1.0.9)
# Requirement already satisfied: langgraph-checkpoint==2.0.21 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 161)) (2.0.21)
# Requirement already satisfied: langgraph-prebuilt==0.1.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 162)) (0.1.3)
# Requirement already satisfied: langgraph-sdk==0.1.57 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 163)) (0.1.57)
# Requirement already satisfied: langgraph==0.3.16 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 164)) (0.3.16)
# Requirement already satisfied: langsmith==0.3.16 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 165)) (0.3.16)
# Requirement already satisfied: lark==1.2.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 166)) (1.2.2)
# Requirement already satisfied: llama-cloud-services==0.6.6 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 167)) (0.6.6)
# Requirement already satisfied: llama-cloud==0.1.15 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 168)) (0.1.15)
# Requirement already satisfied: llama-index-core==0.11.23 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 169)) (0.11.23)
# Requirement already satisfied: llama-index-readers-file==0.2.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 170)) (0.2.2)
# Requirement already satisfied: llama-parse==0.6.4.post1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 171)) (0.6.4.post1)
# Requirement already satisfied: lxml==5.3.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 172)) (5.3.1)
# Requirement already satisfied: lz4==4.4.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 173)) (4.4.3)
# Requirement already satisfied: markdown-it-py==3.0.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 174)) (3.0.0)
# Requirement already satisfied: markdown==3.7 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 175)) (3.7)
# Requirement already satisfied: markupsafe==3.0.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 176)) (3.0.2)
# Requirement already satisfied: marshmallow==3.26.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 177)) (3.26.1)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 178)) (0.1.7)
# Requirement already satisfied: matplotlib==3.10.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 179)) (3.10.1)
# Requirement already satisfied: mdurl==0.1.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 180)) (0.1.2)
# Requirement already satisfied: milvus-lite==2.4.11 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 181)) (2.4.11)
# Requirement already satisfied: mistune==3.1.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 182)) (3.1.2)
# Requirement already satisfied: mmh3==4.1.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 183)) (4.1.0)
# Requirement already satisfied: monotonic==1.6 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 184)) (1.6)
# Requirement already satisfied: mpmath==1.3.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 185)) (1.3.0)
# Requirement already satisfied: msal-extensions==1.3.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 186)) (1.3.1)
# Requirement already satisfied: msal==1.32.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 187)) (1.32.0)
# Requirement already satisfied: msgpack==1.1.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 188)) (1.1.0)
# Requirement already satisfied: multidict==6.2.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 189)) (6.2.0)
# Requirement already satisfied: multiprocess==0.70.16 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 190)) (0.70.16)
# Requirement already satisfied: mypy-extensions==1.0.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 191)) (1.0.0)
# Requirement already satisfied: mypy==1.15.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 192)) (1.15.0)
# Requirement already satisfied: narwhals==1.31.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 193)) (1.31.0)
# Requirement already satisfied: nbclient==0.10.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 194)) (0.10.2)
# Requirement already satisfied: nbconvert==7.16.6 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 195)) (7.16.6)
# Requirement already satisfied: nbformat==5.10.4 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 196)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 197)) (1.6.0)
# Requirement already satisfied: networkx==3.4.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 198)) (3.4.2)
# Requirement already satisfied: nltk==3.9.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 199)) (3.9.1)
# Requirement already satisfied: notebook-shim==0.2.4 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 200)) (0.2.4)
# Requirement already satisfied: notebook==7.3.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 201)) (7.3.3)
# Requirement already satisfied: numpy==1.26.4 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 202)) (1.26.4)
# Requirement already satisfied: oauthlib==3.2.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 216)) (3.2.2)
# Requirement already satisfied: olefile==0.47 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 217)) (0.47)
# Requirement already satisfied: ollama==0.4.7 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 218)) (0.4.7)
# Requirement already satisfied: omegaconf==2.3.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 219)) (2.3.0)
# Requirement already satisfied: onnx==1.17.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 220)) (1.17.0)
# Requirement already satisfied: onnxruntime==1.21.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 221)) (1.21.0)
# Requirement already satisfied: open-clip-torch==2.31.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 222)) (2.31.0)
# Requirement already satisfied: openai==1.66.5 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 223)) (1.66.5)
# Requirement already satisfied: opencv-python==4.11.0.86 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 224)) (4.11.0.86)
# Requirement already satisfied: openpyxl==3.1.5 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 225)) (3.1.5)
# ...
# Requirement already satisfied: requests==2.32.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 309)) (2.32.3)
# Requirement already satisfied: rfc3339-validator==0.1.4 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 310)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 311)) (0.1.1)
# Requirement already satisfied: rich==13.9.4 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 312)) (13.9.4)
# Requirement already satisfied: rouge-score==0.1.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 313)) (0.1.2)
# Requirement already satisfied: rpds-py==0.23.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 314)) (0.23.1)
# Requirement already satisfied: rsa==4.9 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 315)) (4.9)
# Requirement already satisfied: safetensors==0.5.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 316)) (0.5.3)
# Requirement already satisfied: scikit-learn==1.6.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 317)) (1.6.1)
# Requirement already satisfied: scipy==1.15.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 318)) (1.15.2)
# Requirement already satisfied: seaborn==0.13.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 319)) (0.13.2)
# Requirement already satisfied: send2trash==1.8.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 320)) (1.8.3)
# Requirement already satisfied: sentence-transformers==3.4.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 321)) (3.4.1)
# Requirement already satisfied: setuptools==76.1.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 322)) (76.1.0)
# Requirement already satisfied: sgmllib3k==1.0.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 323)) (1.0.0)
# Requirement already satisfied: shapely==2.0.7 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 324)) (2.0.7)
# Requirement already satisfied: shellingham==1.5.4 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 325)) (1.5.4)
# Requirement already satisfied: simsimd==6.2.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 326)) (6.2.1)
# Requirement already satisfied: six==1.17.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 327)) (1.17.0)
# Requirement already satisfied: smmap==5.0.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 328)) (5.0.2)
# Requirement already satisfied: sniffio==1.3.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 329)) (1.3.1)
# Requirement already satisfied: soupsieve==2.6 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 330)) (2.6)
# Requirement already satisfied: sqlalchemy==2.0.39 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 331)) (2.0.39)
# Requirement already satisfied: stack-data==0.6.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 333)) (0.6.3)
# Requirement already satisfied: starlette==0.46.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 334)) (0.46.1)
# Requirement already satisfied: streamlit==1.43.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 335)) (1.43.2)
# Requirement already satisfied: striprtf==0.0.26 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 336)) (0.0.26)
# Requirement already satisfied: sympy==1.13.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 337)) (1.13.1)
# Requirement already satisfied: tavily-python==0.5.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 338)) (0.5.1)
# Requirement already satisfied: tenacity==8.5.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 339)) (8.5.0)
# Requirement already satisfied: terminado==0.18.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 340)) (0.18.1)
# Requirement already satisfied: threadpoolctl==3.6.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 341)) (3.6.0)
# Requirement already satisfied: tiktoken==0.9.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 342)) (0.9.0)
# Requirement already satisfied: timm==1.0.15 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 343)) (1.0.15)
# Requirement already satisfied: tinycss2==1.4.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 344)) (1.4.0)
# Requirement already satisfied: tokenizers==0.21.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 345)) (0.21.1)
# Requirement already satisfied: toml==0.10.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 346)) (0.10.2)
# Requirement already satisfied: torch==2.6.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 347)) (2.6.0)
# Requirement already satisfied: torchvision==0.21.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 348)) (0.21.0)
# Requirement already satisfied: tornado==6.4.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 349)) (6.4.2)
# Requirement already satisfied: tqdm==4.67.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 350)) (4.67.1)
# Requirement already satisfied: traitlets==5.14.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 351)) (5.14.3)
# Requirement already satisfied: transformers==4.49.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 352)) (4.49.0)
# Requirement already satisfied: typer==0.15.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 354)) (0.15.2)
# Requirement already satisfied: types-python-dateutil==2.9.0.20241206 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 355)) (2.9.0.20241206)
# Requirement already satisfied: types-pyyaml==6.0.12.20241230 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 356)) (6.0.12.20241230)
# Requirement already satisfied: types-requests==2.32.0.20250306 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 357)) (2.32.0.20250306)
# Requirement already satisfied: typing-extensions==4.12.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 358)) (4.12.2)
# Requirement already satisfied: typing-inspect==0.9.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 359)) (0.9.0)
# Requirement already satisfied: typing-inspection==0.4.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 360)) (0.4.0)
# Requirement already satisfied: tzdata==2025.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 361)) (2025.1)
# Requirement already satisfied: ujson==5.10.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 362)) (5.10.0)
# Requirement already satisfied: unstructured-client==0.31.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 363)) (0.31.1)
# Requirement already satisfied: unstructured-inference==0.8.10 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 364)) (0.8.10)
# Requirement already satisfied: unstructured-pytesseract==0.3.15 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 365)) (0.3.15)
# Requirement already satisfied: unstructured==0.17.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from unstructured[all-docs]==0.17.0->-r requirements.txt (line 366)) (0.17.0)
# Requirement already satisfied: uri-template==1.3.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 367)) (1.3.0)
# Requirement already satisfied: urllib3==2.3.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 368)) (2.3.0)
# Requirement already satisfied: uvicorn==0.34.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from uvicorn[standard]==0.34.0->-r requirements.txt (line 369)) (0.34.0)
# Requirement already satisfied: uvloop==0.21.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 370)) (0.21.0)
# Requirement already satisfied: watchfiles==1.0.4 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 372)) (1.0.4)
# Requirement already satisfied: wcwidth==0.2.13 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 373)) (0.2.13)
# Requirement already satisfied: webcolors==24.11.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 374)) (24.11.1)
# Requirement already satisfied: webencodings==0.5.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 375)) (0.5.1)
# Requirement already satisfied: websocket-client==1.8.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 376)) (1.8.0)
# Requirement already satisfied: websockets==15.0.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 377)) (15.0.1)
# Requirement already satisfied: widgetsnbextension==4.0.13 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 378)) (4.0.13)
# Requirement already satisfied: wikipedia==1.4.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 379)) (1.4.0)
# Requirement already satisfied: wrapt==1.17.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 380)) (1.17.2)
# Requirement already satisfied: xlrd==2.0.1 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 381)) (2.0.1)
# Requirement already satisfied: xlsxwriter==3.2.2 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 382)) (3.2.2)
# Requirement already satisfied: xxhash==3.5.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 383)) (3.5.0)
# Requirement already satisfied: yarl==1.18.3 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 384)) (1.18.3)
# Requirement already satisfied: zipp==3.21.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 385)) (3.21.0)
# Requirement already satisfied: zstandard==0.23.0 in /Users/hadongheon/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages (from -r requirements.txt (line 386)) (0.23.0)

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_teddynote import logging
logging.langsmith("AI-AGENT")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# AI-AGENT

# %% [markdown]
# # MCP
#
# LangGraph 기반으로 MCP 개념을 반영

# %%
from pydantic import BaseModel
from typing import Dict, Any
from langgraph.graph import StateGraph, END
from langchain_openai import ChatOpenAI
from langchain.schema import SystemMessage

# %% [markdown]
# ## 1. 모델 정의

# %%
llm = ChatOpenAI(model='gpt-4o', temperature=0)

# %% [markdown]
# ## 2. Agent 정의

# %%
search_prompt = SystemMessage(content="당신은 검색 전문가입니다. 전기차 시장 관련 최신 뉴스들을 검색하고 정리한 내용들을 출력하세요.")
derivate_prompt = SystemMessage(content="당신은 도출 전문가입니다. 소비자 우려 요인을 도출하고 정리한 내용들을 출력하세요.")
come_up_with_prompt = SystemMessage(content="당신은 기획 전문가입니다. 마케팅 캠페인 아이디어를 생성하고 정리한 내용들을 출력하세요.")
documentate_prompt = SystemMessage(content="당신은 문서화 전문가입니다. 결과들을 정리 후 제안서를 생성 및 저장하세요.")

# %%
# MCP 사상 반영: context에 agent/task/result를 구조화하여 명시
class AgentState(BaseModel):
    topic: str
    context: Dict[str, Any]

# %%
def search_agent(state: AgentState) -> AgentState:
    topic = state.topic 
    
    messages = [
        search_prompt,
        {"role": "user", "content": f"{topic}에 대해 조사해 주세요."}
    ]

    search_result = llm.invoke(messages)

    # MCP 사상 반영: context에 agent/task/result를 구조화하여 명시
    return AgentState(
        topic=state.topic,
        context={
            "agent": "SearchAgent",
            "task": "search",
            "result": search_result.content
        }
    )

# %%
def derivate_agent(state: AgentState) -> AgentState:
    search_text = state.context["result"]

    messages = [
        derivate_prompt,
        {"role": "user", "content": f"다음 정보에서 소비자 우려 요인을 도출해주세요:\n{search_text}"}
    ]

    derivate_result = llm.invoke(messages)

    # MCP 사상 반영: context에 agent/task/result를 구조화하여 명시
    return AgentState(
        topic=state.topic,
        context={
            "agent": "DerivateAgent",
            "task": "derivate",
            "result": derivate_result.content
        }
    )

# %%
def come_up_with_agent(state: AgentState) -> AgentState:
    derivate_text = state.context["result"]

    messages = [
        come_up_with_prompt,
        {"role": "user", "content": "다음 소비자 우려 요인들로 마케팅 캠페인 아이디어를 생성해주세요:\n{derivate_text}"}
    ]

    come_up_with_result = llm.invoke(messages)

    # MCP 사상 반영: context에 agent/task/result를 구조화하여 명시
    return AgentState(
        topic=state.topic,
        context={
            "agent": "ComeupwithAgent",
            "task": "come_up_with",
            "result": come_up_with_result.content
        }
    )

# %%
def documentate_agent(state: AgentState) -> AgentState:
    come_up_with_text = state.context["result"]

    messages = [
        documentate_prompt,
        {"role": "user", "content": f"다음 정보를 문서화해 요약해주세요:\n{come_up_with_text}"}
    ]

    documentate_result = llm.invoke(messages)

    # MCP 사상 반영: 에이전트별 task와 결과를 context로 저장
    return AgentState(
        topic=state.topic,
        context={
            "agent": "DocumentateAgent",
            "task": "documentate",
            "result": documentate_result.content
        }
    )

# %% [markdown]
# ## 3. Workflow 설계

# %%
workflow = StateGraph(AgentState)

workflow.add_node("search", search_agent)
workflow.add_node("derivate", derivate_agent)
workflow.add_node("come_up_with", come_up_with_agent)
workflow.add_node("documentate", documentate_agent)

# 엔트리 포인트 설정
workflow.set_entry_point("search")

# 엣지 설정
workflow.add_edge("search", "derivate")
workflow.add_edge("derivate", "come_up_with")
workflow.add_edge("come_up_with", "documentate")
workflow.add_edge("documentate", END)

# 그래프 컴파일
graph = workflow.compile()

# %%
from langchain_teddynote.graphs import visualize_graph

visualize_graph(graph)

# %% [markdown]
# ## 4. 실행

# %%
# 실행 예시
initial_state = {
    "topic": "전기차 시장의 최근 이슈",
    "context": {}
}

# %%
result = graph.invoke(initial_state)
print("🔍 조사 내용:\n", result["context"]["result"])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 result = graph.invoke(initial_state)
#       2 print("🔍 조사 내용:\n", result["context"]["result"])
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/langgraph/pregel/__init__.py:2392, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    2390 else:
#    2391     chunks = []
# -> 2392 for chunk in self.stream(
#    2393     input,
#    2394     config,
#    2395     stream_mode=stream_mode,
#    2396     output_keys=output_keys,
#    2397     interrupt_before=interrupt_before,
#    2398     interrupt_after=interrupt_after,
#    2399     debug=debug,
#    2400     **kwargs,
#    2401 ):
#    2402     if stream_mode == "values":
#    2403         latest = chunk
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/langgraph/pregel/__init__.py:2046, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    2040     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2041     # computation proceeds in steps, while there are channel updates.
#    2042     # Channel updates from step N are only visible in step N+1
#    2043     # channels are guaranteed to be immutable for the duration of the step,
#    2044     # with channel updates applied only at the transition between steps.
#    2045     while loop.tick(input_keys=self.input_channels):
# -> 2046         for _ in runner.tick(
#    2047             loop.tasks.values(),
#    2048             timeout=self.step_timeout,
#    2049             retry_policy=self.retry_policy,
#    2050             get_waiter=get_waiter,
#    2051         ):
#    2052             # emit output
#    2053             yield from output()
#    2054 # emit output
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/langgraph/pregel/runner.py:146, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     144 t = tasks[0]
#     145 try:
# --> 146     run_with_retry(
#     147         t,
#     148         retry_policy,
#     149         configurable={
#     150             CONFIG_KEY_CALL: partial(
#     151                 _call,
#     152                 t,
#     153                 retry=retry_policy,
#     154                 futures=weakref.ref(futures),
#     155                 schedule_task=self.schedule_task,
#     156                 submit=self.submit,
#     157                 reraise=reraise,
#     158             ),
#     159         },
#     160     )
#     161     self.commit(t, None)
#     162 except Exception as exc:
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/langgraph/pregel/retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/langgraph/utils/runnable.py:546, in RunnableSeq.invoke(self, input, config, **kwargs)
#     542 config = patch_config(
#     543     config, callbacks=run_manager.get_child(f"seq:step:{i + 1}")
#     544 )
#     545 if i == 0:
# --> 546     input = step.invoke(input, config, **kwargs)
#     547 else:
#     548     input = step.invoke(input, config)
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/langgraph/utils/runnable.py:310, in RunnableCallable.invoke(self, input, config, **kwargs)
#     308 else:
#     309     context.run(_set_config_context, config)
# --> 310     ret = context.run(self.func, *args, **kwargs)
#     311 if isinstance(ret, Runnable) and self.recurse:
#     312     return ret.invoke(input, config)
#
# Cell In[42], line 9, in search_agent(state)
#       2 topic = state.topic
#       4 messages = [
#       5     search_prompt,
#       6     {"role": "user", "content": f"{topic}에 대해 조사해 주세요."}
#       7 ]
# ----> 9 search_result = llm.invoke(messages)
#      11 # MCP 사상 반영: context에 agent/task/result를 구조화하여 명시
#      12 return AgentState(
#      13     topic=state.topic,
#      14     context={
#    (...)     18     }
#      19 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:307, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     296 def invoke(
#     297     self,
#     298     input: LanguageModelInput,
#    (...)    302     **kwargs: Any,
#     303 ) -> BaseMessage:
#     304     config = ensure_config(config)
#     305     return cast(
#     306         ChatGeneration,
# --> 307         self.generate_prompt(
#     308             [self._convert_input(input)],
#     309             stop=stop,
#     310             callbacks=config.get("callbacks"),
#     311             tags=config.get("tags"),
#     312             metadata=config.get("metadata"),
#     313             run_name=config.get("run_name"),
#     314             run_id=config.pop("run_id", None),
#     315             **kwargs,
#     316         ).generations[0][0],
#     317     ).message
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:843, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     835 def generate_prompt(
#     836     self,
#     837     prompts: list[PromptValue],
#    (...)    840     **kwargs: Any,
#     841 ) -> LLMResult:
#     842     prompt_messages = [p.to_messages() for p in prompts]
# --> 843     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:683, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     680 for i, m in enumerate(messages):
#     681     try:
#     682         results.append(
# --> 683             self._generate_with_cache(
#     684                 m,
#     685                 stop=stop,
#     686                 run_manager=run_managers[i] if run_managers else None,
#     687                 **kwargs,
#     688             )
#     689         )
#     690     except BaseException as e:
#     691         if run_managers:
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:908, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     906 else:
#     907     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 908         result = self._generate(
#     909             messages, stop=stop, run_manager=run_manager, **kwargs
#     910         )
#     911     else:
#     912         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:925, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     923     generation_info = {"headers": dict(raw_response.headers)}
#     924 else:
# --> 925     response = self.client.create(**payload)
#     926 return self._create_chat_result(response, generation_info)
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/openai/resources/chat/completions/completions.py:914, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     871 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     872 def create(
#     873     self,
#    (...)    911     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     912 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     913     validate_response_format(response_format)
# --> 914     return self._post(
#     915         "/chat/completions",
#     916         body=maybe_transform(
#     917             {
#     918                 "messages": messages,
#     919                 "model": model,
#     920                 "audio": audio,
#     921                 "frequency_penalty": frequency_penalty,
#     922                 "function_call": function_call,
#     923                 "functions": functions,
#     924                 "logit_bias": logit_bias,
#     925                 "logprobs": logprobs,
#     926                 "max_completion_tokens": max_completion_tokens,
#     927                 "max_tokens": max_tokens,
#     928                 "metadata": metadata,
#     929                 "modalities": modalities,
#     930                 "n": n,
#     931                 "parallel_tool_calls": parallel_tool_calls,
#     932                 "prediction": prediction,
#     933                 "presence_penalty": presence_penalty,
#     934                 "reasoning_effort": reasoning_effort,
#     935                 "response_format": response_format,
#     936                 "seed": seed,
#     937                 "service_tier": service_tier,
#     938                 "stop": stop,
#     939                 "store": store,
#     940                 "stream": stream,
#     941                 "stream_options": stream_options,
#     942                 "temperature": temperature,
#     943                 "tool_choice": tool_choice,
#     944                 "tools": tools,
#     945                 "top_logprobs": top_logprobs,
#     946                 "top_p": top_p,
#     947                 "user": user,
#     948                 "web_search_options": web_search_options,
#     949             },
#     950             completion_create_params.CompletionCreateParams,
#     951         ),
#     952         options=make_request_options(
#     953             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     954         ),
#     955         cast_to=ChatCompletion,
#     956         stream=stream or False,
#     957         stream_cls=Stream[ChatCompletionChunk],
#     958     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/openai/_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)   1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/openai/_base_client.py:919, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     916 else:
#     917     retries_taken = 0
# --> 919 return self._request(
#     920     cast_to=cast_to,
#     921     options=options,
#     922     stream=stream,
#     923     stream_cls=stream_cls,
#     924     retries_taken=retries_taken,
#     925 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/openai/_base_client.py:1008, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1006 if remaining_retries > 0 and self._should_retry(err.response):
#    1007     err.response.close()
# -> 1008     return self._retry_request(
#    1009         input_options,
#    1010         cast_to,
#    1011         retries_taken=retries_taken,
#    1012         response_headers=err.response.headers,
#    1013         stream=stream,
#    1014         stream_cls=stream_cls,
#    1015     )
#    1017 # If the response is streamed then we need to explicitly read the response
#    1018 # to completion before attempting to access the response text.
#    1019 if not err.response.is_closed:
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/openai/_base_client.py:1057, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1053 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1054 # different thread if necessary.
#    1055 time.sleep(timeout)
# -> 1057 return self._request(
#    1058     options=options,
#    1059     cast_to=cast_to,
#    1060     retries_taken=retries_taken + 1,
#    1061     stream=stream,
#    1062     stream_cls=stream_cls,
#    1063 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/openai/_base_client.py:1008, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1006 if remaining_retries > 0 and self._should_retry(err.response):
#    1007     err.response.close()
# -> 1008     return self._retry_request(
#    1009         input_options,
#    1010         cast_to,
#    1011         retries_taken=retries_taken,
#    1012         response_headers=err.response.headers,
#    1013         stream=stream,
#    1014         stream_cls=stream_cls,
#    1015     )
#    1017 # If the response is streamed then we need to explicitly read the response
#    1018 # to completion before attempting to access the response text.
#    1019 if not err.response.is_closed:
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/openai/_base_client.py:1057, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1053 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1054 # different thread if necessary.
#    1055 time.sleep(timeout)
# -> 1057 return self._request(
#    1058     options=options,
#    1059     cast_to=cast_to,
#    1060     retries_taken=retries_taken + 1,
#    1061     stream=stream,
#    1062     stream_cls=stream_cls,
#    1063 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/model-serving-MrWqFMXe-py3.11/lib/python3.11/site-packages/openai/_base_client.py:1023, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1020         err.response.read()
#    1022     log.debug("Re-raising status error")
# -> 1023     raise self._make_status_error_from_response(err.response) from None
#    1025 return self._process_response(
#    1026     cast_to=cast_to,
#    1027     options=options,
#    (...)   1031     retries_taken=retries_taken,
#    1032 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# During task with name 'search' and id '0101af2e-7993-8c8d-6cff-46fbacfb999b'

# %% [markdown]
# --------
# ** End of Documents **
